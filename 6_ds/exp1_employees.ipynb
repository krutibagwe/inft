# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/employees.csv - employees.csv.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    998 non-null    object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            999 non-null    float64
#  6   Senior Management  933 non-null    object
#  7   Team               953 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.head(5) # head
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance
# 3              True    Finance
# 4              True        NaN

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df["Team"].nunique()
# Out:
# 11

# %%
df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', '0', 'Engineering',
#        'Business Development', 'Legal', 'Human Resources', 'Product',
#        'Client Services', 'Sales', 'Distribution'], dtype=object)

# %%
df.columns.nunique()
# Out:
# 8

# %%
df['Team'].value_counts()
# Out:
# Team
# Client Services         105
# Finance                 101
# Business Development    101
# Marketing                98
# Product                  94
# Sales                    93
# Engineering              92
# Human Resources          90
# Distribution             90
# Legal                    87
# 0                         2
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        2
# Salary                 0
# Bonus %                1
# Senior Management     67
# Team                  47
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# First Name            6.7
# Gender               14.5
# Start Date            0.0
# Last Login Time       0.2
# Salary                0.0
# Bonus %               0.1
# Senior Management     6.7
# Team                  4.7
# dtype: float64

# %%
df.dropna(subset=['Team'], inplace=True)

# %%
df = df[df['Team'] != '0']

# %%
df = df.dropna(subset=['Last Login Time'])

# %%
df['First Name'] = df['First Name'].fillna('Unknown')

# %%
df_copy = df.copy()
df_copy['Gender'] = df_copy['Gender'].fillna(df_copy['Gender'].mode()[0])

# %%
df.isnull().sum()
# Out:
# First Name            0
# Gender                0
# Start Date            0
# Last Login Time       0
# Salary                0
# Bonus %               1
# Senior Management    57
# Team                  0
# dtype: int64

# %%
df_copy = df.copy()
df_copy['Bonus %'] = df_copy['Bonus %'].fillna(df_copy['Bonus %'].mean())

# %%
df_copy = df.copy()
df_copy['Senior Management'] = df_copy['Senior Management'].fillna(df_copy['Senior Management'].mode()[0])

# %%
df.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
df['First Name']
# Out:
# 0      Douglas
# 2        Maria
# 3        Jerry
# 9      Frances
# 11       Julie
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 950, dtype: object

# %%
X = df[["First Name", "Gender", "Senior Management"]]
X
# Out:
#     First Name  Gender  Senior Management
# 0      Douglas    Male               True
# 2        Maria  Female              False
# 3        Jerry    Male               True
# 9      Frances  Female               True
# 11       Julie  Female               True
# ..         ...     ...                ...
# 995      Henry  Female              False
# 996    Phillip    Male              False
# 997    Russell    Male              False
# 998      Larry    Male              False
# 999     Albert    Male               True
#
# [950 rows x 3 columns]

# %%
df.iloc[:, [1,2,4]]
# Out:
#      Gender  Start Date  Salary
# 0      Male  08-06-1993   97308
# 2    Female   4/23/1993  130590
# 3      Male  03-04-2005  138705
# 9    Female  08-08-2002  139852
# 11   Female  10/26/1997  102508
# ..      ...         ...     ...
# 995  Female  11/23/2014  132483
# 996    Male   1/31/1984   42392
# 997    Male   5/20/2013   96914
# 998    Male   4/20/2013   60500
# 999    Male   5/15/2012  129949
#
# [950 rows x 3 columns]

# %%
df.columns.tolist()
# Out:
# ['First Name',
#  'Gender',
#  'Start Date',
#  'Last Login Time',
#  'Salary',
#  'Bonus %',
#  'Senior Management',
#  'Team']

# %%
df.sort_values(by = "Salary", ascending = True)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael    Male   7/30/1993         5:35 PM   35013   14.879
# 238      Kevin    Male   3/25/1982         7:31 AM   35061    5.128
# 82      Steven    Male   3/30/1980         9:20 PM   35095    8.379
# 63     Matthew    Male  01-02-2013        10:33 PM   35203   18.040
# 650    Cynthia  Female  07-05-1986         1:24 AM   35381   11.749
# ..         ...     ...         ...             ...     ...      ...
# 160      Kathy  Female   3/18/2000         7:26 PM  149563   16.991
# 186    Unknown  Female   2/23/2005         9:50 PM  149654    1.825
# 828    Cynthia  Female  07-12-2006         8:55 AM  149684    7.864
# 429       Rose  Female   5/28/2015         8:40 AM  149903    5.630
# 644  Katherine  Female   8/13/1996        12:21 AM  149908   18.912
#
#      Senior Management             Team
# 576              False          Product
# 238              False            Legal
# ...

# %%
df['doubleSalary'] = df["Salary"]*2
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 9      Frances  Female  08-08-2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry  Female  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team  doubleSalary
# 0                 True             Marketing        194616
# ...

# %%
df['topPerformer'] = ["yes" if i>10 else "no" for i in df["Bonus %"]]
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 9      Frances  Female  08-08-2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry  Female  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team  doubleSalary topPerformer
# 0                 True             Marketing        194616           no
# ...

# %%
df.iloc[21:28,]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 31      Joyce  Female   2/20/2005         2:40 PM   88657   12.752
# 33       Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 34      Jerry    Male  01-10-2004        12:56 PM   95734   19.096
# 35    Theresa  Female  10-10-2006         1:12 AM   85182   16.675
# 36     Rachel  Female   2/16/2009         8:47 PM  142032   12.599
# 37      Linda  Female  10/19/1981         8:49 PM   57427    9.557
# 38  Stephanie  Female   9/13/1986         1:52 AM   36844    5.574
#
#     Senior Management                  Team  doubleSalary topPerformer
# 31              False               Product        177314          yes
# 33              False  Business Development        238164          yes
# 34              False       Client Services        191468          yes
# 35              False                 Sales        170364          yes
# 36              False  Business Development        284064          yes
# ...

# %%
df.iloc[13:18, 1:5]
# Out:
#     Gender  Start Date Last Login Time  Salary
# 22  Female  03-08-2012         1:58 AM   90816
# 24    Male  07-01-1992        10:08 PM   97950
# 25    Male  10-08-2012         1:12 AM   37076
# 26    Male   2/27/2000         7:45 AM   37598
# 27  Female  07-11-1991         6:58 PM  122367

# %%
df.sample(10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 541       Ruby  Female  05-01-1999         3:36 AM  147362    7.851
# 119       Paul    Male  06-03-2008         3:05 PM   41054   12.299
# 182    Lillian  Female   6/19/1999         4:44 PM  123940   12.184
# 408        Joe    Male  12-05-2010         4:20 PM  144082    1.620
# 557       Jane  Female  06-01-1994         8:39 AM   42424   18.115
# 644  Katherine  Female   8/13/1996        12:21 AM  149908   18.912
# 468     Janice  Female   6/28/1997         1:48 PM  136032   10.696
# 702      Debra  Female   3/17/2011         1:12 PM   84693    6.976
# 584       Jack    Male   5/30/2012         3:17 AM   70367   18.266
#
#      Senior Management                  Team  doubleSalary topPerformer
# 993               True           Engineering        112900          yes
# 541               True           Engineering        294724           no
# ...

# %%
df[df["Team"].isin(["Legal"])]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 20        Lois  Female   4/22/1995         7:18 PM   64714    4.934
# 27       Scott  Female  07-11-1991         6:58 PM  122367    5.218
# 29    Benjamin    Male   1/26/2005        10:06 PM   79529    7.008
# 42     Beverly  Female  09-09-1998         8:26 PM  121918   15.835
# ..         ...     ...         ...             ...     ...      ...
# 961    Antonio  Female   6/18/1989         9:37 PM  103050    3.050
# 976     Denise  Female  10/19/1992         5:42 AM  137954    4.195
# 981      James    Male   1/15/1993         5:19 PM  148985   19.280
# 985    Stephen  Female  07-10-1983         8:10 PM   85668    1.909
# 989     Justin  Female  02-10-1991         4:58 PM   38344    3.794
#
#      Senior Management   Team  doubleSalary topPerformer
# 11                True  Legal        205016          yes
# ...

# %%
df[df.Salary <= 70000]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15     Lillian  Female  06-05-2016         6:09 AM   59414    1.256
# 20        Lois  Female   4/22/1995         7:18 PM   64714    4.934
# 25     Unknown    Male  10-08-2012         1:12 AM   37076   18.576
# 26       Craig    Male   2/27/2000         7:45 AM   37598    7.757
# ..         ...     ...         ...             ...     ...      ...
# 988      Alice  Female  10-05-2004         9:34 AM   47638   11.209
# 989     Justin  Female  02-10-1991         4:58 PM   38344    3.794
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#      Senior Management                  Team  doubleSalary topPerformer
# 14                True               Finance         82852          yes
# ...

# %%
df[df["Bonus %"].isin([15.0,18.0])]
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 9      Frances  Female  08-08-2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry  Female  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team  doubleSalary topPerformer
# 0                 True             Marketing        194616           no
# ...

# %%
df[(df.Salary > 120000) & (df.Team=="Finance") | (df.Salary < 50000)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 14    Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 25     Unknown    Male  10-08-2012         1:12 AM   37076   18.576
# 26       Craig    Male   2/27/2000         7:45 AM   37598    7.757
# ..         ...     ...         ...             ...     ...      ...
# 984      Maria  Female  10/15/2011         4:53 PM   43455   13.040
# 987     Gloria  Female  12-08-2014         5:08 AM  136709   10.331
# 988      Alice  Female  10-05-2004         9:34 AM   47638   11.209
# 989     Justin  Female  02-10-1991         4:58 PM   38344    3.794
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
#
#      Senior Management             Team  doubleSalary topPerformer
# 2                False          Finance        261180          yes
# ...

# %%
df.drop(df.index[2])
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 9      Frances  Female  08-08-2002         6:51 AM  139852    7.524
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male  12-01-1980         1:08 AM  112807   17.492
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry  Female  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team  doubleSalary topPerformer
# 0                 True             Marketing        194616           no
# ...

# %%
Y = df.groupby("Team")
Y

# %%
df.groupby("Team").nunique()
# Out:
#                       First Name  Gender  Start Date  Last Login Time  Salary  \
# Team
# Business Development          76       2         101              100     101
# Client Services               78       2         105              102     105
# Distribution                  65       2          90               88      90
# Engineering                   71       2          91               90      91
# Finance                       81       2         101               99     101
# Human Resources               67       2          89               90      90
# Legal                         75       2          87               84      87
# Marketing                     74       2          98               96      98
# Product                       74       2          94               89      94
# Sales                         69       2          93               90      93
#
#                       Bonus %  Senior Management  doubleSalary  topPerformer
# Team
# ...
