# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/diabetes.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df["Age"].nunique()
# Out:
# 52

# %%
df["Age"].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68])

# %%
df.columns.nunique()
# Out:
# 9

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
zero_counts = (df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] == 0).sum()
print(zero_counts)
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
columns_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

for col in columns_to_impute:
    median_value = df.loc[df[col] != 0, col].median()
    df[col] = df[col].replace(0, median_value)

# %%
zero_counts = (df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] == 0).sum()
print(zero_counts)
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
df['Glucose']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
Y = df[["Glucose", "BMI", "Age"]]
Y
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %%
df.iloc[:, [1,2,4]]
# Out:
#      Glucose  BloodPressure  Insulin
# 0        148             72      125
# 1         85             66      125
# 2        183             64      125
# 3         89             66       94
# 4        137             40      168
# ..       ...            ...      ...
# 763      101             76      180
# 764      122             70      125
# 765      121             72      112
# 766      126             60      125
# 767       93             70      125
#
# [768 rows x 3 columns]

# %%
df.columns.tolist()
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df.sort_values(by = "Age", ascending = True)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35      125  33.6
# 60             2       84             72             29      125  32.3
# 102            0      125             96             29      125  22.5
# 182            1      117             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80             29      125  26.8
# 684            5      136             82             29      125  32.3
# 666            4      145             82             18      125  32.5
# 453            2      119             72             29      125  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# ...

# %%
df['olderThan50'] = ["yes" if i>50 else "no" for i in df["Age"]]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35      125  33.6
# 1              1       85             66             29      125  26.6
# 2              8      183             64             29      125  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27      125  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             29      125  30.1
# 767            1       93             70             31      125  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 0                       0.627   50        1          no
# ...

# %%
df.iloc[31:37,]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 31            3      158             76             36      245  31.6
# 32            3       88             58             11       54  24.8
# 33            6       92             92             29      125  19.9
# 34           10      122             78             31      125  27.6
# 35            4      103             60             33      192  24.0
# 36           11      138             76             29      125  33.2
#
#     DiabetesPedigreeFunction  Age  Outcome olderThan50
# 31                     0.851   28        1          no
# 32                     0.267   22        0          no
# 33                     0.188   28        0          no
# 34                     0.512   45        0          no
# 35                     0.966   33        0          no
# 36                     0.420   35        0          no

# %%
df.iloc[56:64, 1:4]
# Out:
#     Glucose  BloodPressure  SkinThickness
# 56      187             68             39
# 57      100             88             60
# 58      146             82             29
# 59      105             64             41
# 60       84             72             29
# 61      133             72             29
# 62       44             62             29
# 63      141             58             34

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 582           12      121             78             17      125  26.5
# 607            1       92             62             25       41  19.5
# 647            0      179             50             36      159  37.8
# 67             2      109             92             29      125  42.7
# 702            1      168             88             29      125  35.0
# 678            3      121             52             29      125  36.0
# 665            1      112             80             45      132  34.8
# 636            5      104             74             29      125  28.8
# 583            8      100             76             29      125  38.7
# 303            5      115             98             29      125  52.9
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 582                     0.259   62        0         yes
# 607                     0.482   25        0          no
# ...

# %%
df[df["Outcome"].isin([1])]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35      125  33.6
# 2              8      183             64             29      125  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72             29      125  36.3
# 759            6      190             92             29      125  35.5
# 761            9      170             74             31      125  44.0
# 766            1      126             60             29      125  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 0                       0.627   50        1          no
# ...

# %%
df[df.Glucose >= 190]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 22             7      196             90             29      125  39.8
# 185            7      194             68             28      125  35.9
# 206            8      196             76             29      280  37.5
# 228            4      197             70             39      744  36.7
# 258            1      193             50             16      375  25.9
# 260            3      191             68             15      130  30.9
# 319            6      194             78             29      125  23.5
# 359            1      196             76             36      249  36.5
# 399            3      193             70             31      125  34.9
# 408            8      197             74             29      125  25.9
# 489            8      194             80             29      125  26.1
# ...

# %%
df[df["BMI"].isin([23.0,25.0])]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 55             1       73             50             10      125  23.0
# 62             5       44             62             29      125  25.0
# 79             2      112             66             22      125  25.0
# 272            3      122             78             29      125  23.0
# 509            8      120             78             29      125  25.0
# 520            2       68             70             32       66  25.0
# 581            6      109             60             27      125  25.0
# 697            0       99             72             29      125  25.0
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 55                      0.248   21        0          no
# 62                      0.587   36        0          no
# 79                      0.307   24        0          no
# 272                     0.254   40        0          no
# ...

# %%
df[(df.Age > 50) & (df.Glucose > 170) | (df.BMI > 40)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 16             0      118             84             47      230  45.8
# 18             1      103             30             38       83  43.3
# ..           ...      ...            ...            ...      ...   ...
# 746            1      147             94             41      125  49.3
# 747            1       81             74             41       57  46.3
# 753            0      181             88             44      510  43.3
# 759            6      190             92             29      125  35.5
# 761            9      170             74             31      125  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 4                       2.288   33        1          no
# ...

# %%
df.drop(df.index[1])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35      125  33.6
# 2              8      183             64             29      125  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74             29      125  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27      125  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             29      125  30.1
# 767            1       93             70             31      125  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome olderThan50
# 0                       0.627   50        1          no
# ...

# %%
df.groupby("Outcome")["Glucose"].mean()
# Out:
# Outcome
# 0    110.682000
# 1    142.130597
# Name: Glucose, dtype: float64

# %%
df.groupby("Outcome").nunique()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                 14      110             42             45      136  210
# 1                 17      103             38             42       92  147
#
#          DiabetesPedigreeFunction  Age  olderThan50
# Outcome
# 0                             372   51            2
# 1                             231   45            2
